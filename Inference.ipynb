# %%
import os
os.getcwd()
"""Convert files of a selected directory in jpg format"""
import converter
# converter.convertToJpg('/Users/neerajyadav/Documents/pycv/TestImage')

# %%
# !pip install easyocr
import easyocr
#download the model
reader = easyocr.Reader(['en'], gpu = True)
# show an image
import PIL
from PIL import ImageDraw
from PIL import Image
import cv2
import PIL
from PIL import ImageDraw
from PIL import Image
import cv2
import pandas as pd
from pandas import DataFrame
import pandas as pd
import json
import glob
# import xlrd
import csv
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
"""Select jpg files and convert into transcript files"""
filenames = glob.glob("/Users/neerajyadav/Documents/pycv/TestImage/*.jpg")
filenamesj = glob.glob("/Users/neerajyadav/Documents/pycv/TestImage/*.jpeg")
filenames = filenames + filenamesj
filenames.sort()

# %%
def draw_boxes(image, bounds, color='green', width=1):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color , width=width)
        # if bound[1] == "ToTAL" or bound[1] =="TOTAL" or bound[1]=="TOTAL" or bound[1] =="Total Payable;" or bound[1] =="Total Payable:" or bound[1] =="Total Payable:" or bound[1]=='Total' or bound[1]=='TOTAL' or bound[1]=="Totz' Ingi, 0f GST" or bound[1]=="Total Sales (Inclusive of GST)" or bound[1]=="Net Total (MYR)":
          # draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
          # print(bound[0])
          # image.save("temp.jpg")
    return image
# draw_boxes(im, bounds)
def concatenate_list_data(list):
    result= ''
    for element in list:
        result = result +str(element)
    return result


for s in filenames:
    # s = "Invoice0.jpg"
    filen = s.split(".")[0]
    print(filen)
    im = PIL.Image.open(s).convert('RGB')
    # Doing OCR. Get bounding boxes.
    bounds = reader.readtext(s)
    im = PIL.Image.open(s).convert('RGB')
    df = pd.DataFrame()
    CoordinatesValue = []
    for i in bounds:
        Coordinates =[]
        CoordinatesValue=[]
        temp_df = pd.DataFrame()
        Coordinates.append(concatenate_list_data(i[0]).replace("][",",").replace("[","").replace("]","").replace(" ",""))
#         print(i[1])
        CoordinatesValue.append(i[1])
        temp_df = DataFrame(zip(Coordinates,CoordinatesValue),columns = ['Coordinates', 'Value'])
#         print(temp_df)
        df = df.append(temp_df)
    # print(item[0])
    combine_lambda = lambda x: '{},{}'.format(x.Coordinates, x.Value)
    df['Result'] = df.apply(combine_lambda, axis = 1)
    dfnew= df['Result']
    dfnew = dfnew[0].str.split(',', expand=True)
    dfnew.insert(0,'name_of_column','')
    dfnew['name_of_column'] = 1
#     dfnew.to_csv(str(filen)+".tsv",  sep = ',',index=False ,header=False )
    dfnew.to_csv(str(filen)+".tsv",sep = ',',index=False,header=False, quotechar='',escapechar='\\',quoting=csv.QUOTE_NONE, )
# Out:
# /Users/neerajyadav/Documents/pycv/TestImage/ReceiptSwiss
# Berghote ]
#                        Coordinates       Value
# 0  495,218,751,218,751,279,495,279  Berghote ]
# Grosse
#                        Coordinates   Value
# 0  414,270,590,270,590,326,414,326  Grosse
# Sche idegg
#                        Coordinates       Value
# 0  605,261,872,261,872,346,605,346  Sche idegg
# 3818 GrindelwaId
#                        Coordinates             Value
# 0  468,322,776,322,776,370,468,370  3818 GrindelwaId
# Fami Iie R. Mu | ler
#                        Coordinates                 Value
# 0  468,372,776,372,776,420,468,420  Fami Iie R. Mu | ler
# Rech. Nr .
#                        Coordinates       Value
# 0  191,477,335,477,335,521,191,521  Rech. Nr .
# 4572
#                        Coordinates Value
# 0  359,477,443,477,443,521,359,521  4572
# 30.07.2007/13:29:17
#                        Coordinates                Value
# 0  634,476,994,476,994,526,634,526  30.07.2007/13:29:17
# Bar
#                        Coordinates Value
# 0  191,529,257,529,257,573,191,573   Bar
# Tisch
#                        Coordinates  Value
# 0  763,527,868,527,868,577,763,577  Tisch
# 7/01
#                        Coordinates Value
# 0  910,528,994,528,994,578,910,578  7/01
# 2xLatte Macchiato
#                        Coordinates              Value
# 0  208,632,536,632,536,680,208,680  2xLatte Macchiato
# a
#                        Coordinates Value
# 0  582,640,606,640,606,674,582,674     a
# 4,50
#                        Coordinates Value
# 0  655,635,739,635,739,677,655,677  4,50
# CHF
#                        Coordinates Value
# 0  765,635,831,635,831,677,765,677   CHF
# 9.00
#                        Coordinates Value
# 0  895,635,977,635,977,679,895,679  9.00
# IxGloki
#                        Coordinates    Value
# 0  214,682,348,682,348,730,214,730  IxGloki
# a
#                        Coordinates Value
# 0  585,691,605,691,605,723,585,723     a
# 5.00
#                        Coordinates Value
# 0  655,685,741,685,741,727,655,727  5.00
# CHF
#                        Coordinates Value
# 0  767,685,831,685,831,727,767,727   CHF
# 5.00
#                        Coordinates Value
# 0  896,682,982,682,982,732,896,732  5.00
# IxSchweinschnitze]
#                        Coordinates               Value
# 0  214,732,552,732,552,780,214,780  IxSchweinschnitze]
# 3
#                        Coordinates Value
# 0  585,741,605,741,605,771,585,771     3
# 22.00
#                        Coordinates  Value
# 0  637,733,741,733,741,777,637,777  22.00
# CHF
#                        Coordinates Value
# 0  767,735,831,735,831,777,767,777   CHF
# 22.00
#                        Coordinates  Value
# 0  876,732,980,732,980,780,876,780  22.00
# IxChasspatz]i
#                        Coordinates          Value
# 0  212,784,458,784,458,834,212,834  IxChasspatz]i
# a
#                        Coordinates Value
# 0  587,791,607,791,607,823,587,823     a
# 18.50
#                        Coordinates  Value
# 0  643,785,741,785,741,827,643,827  18.50
# CHF
#                        Coordinates Value
# 0  767,785,833,785,833,829,767,829   CHF
# 18. 50
#                        Coordinates   Value
# 0  883,785,981,785,981,829,883,829  18. 50
# Tota]
#                        Coordinates  Value
# 0  434,892,536,892,536,940,434,940  Tota]
# CHF
#                        Coordinates Value
# 0  639,893,705,893,705,937,639,937   CHF
# 54,50
#                        Coordinates  Value
# 0  805,883,955,883,955,943,805,943  54,50
# Inc1 .
#                          Coordinates   Value
# 0  188,993,280,993,280,1043,188,1043  Inc1 .
# 7. 6% MwSt
#                          Coordinates       Value
# 0  304,994,482,994,482,1042,304,1042  7. 6% MwSt
# 54.50 CHF:
#                          Coordinates       Value
# 0  526,992,722,992,722,1040,526,1040  54.50 CHF:
# 3.85
#                          Coordinates Value
# 0  793,993,875,993,875,1037,793,1037  3.85
# Entspricht in Euro
#                            Coordinates               Value
# 0  188,1101,539,1101,539,1152,188,1152  Entspricht in Euro
# 36.33
#                            Coordinates  Value
# 0  584,1100,690,1100,690,1148,584,1148  36.33
# EUR
#                            Coordinates Value
# 0  714,1098,785,1098,785,1148,714,1148   EUR
# Es bediente Sie: Ursula
#                            Coordinates                    Value
# 0  186,1154,632,1154,632,1204,186,1204  Es bediente Sie: Ursula
# MwSt Nr
#                            Coordinates    Value
# 0  470,1260,618,1260,618,1308,470,1308  MwSt Nr
# 430 234
#                            Coordinates    Value
# 0  660,1258,804,1258,804,1306,660,1306  430 234
# Te].
#                            Coordinates Value
# 0  434,1312,516,1312,516,1360,434,1360  Te].
# 033 853 67 16
#                            Coordinates          Value
# 0  546,1312,804,1312,804,1360,546,1360  033 853 67 16
# Fax.
#                            Coordinates Value
# 0  435,1367,513,1367,513,1411,435,1411  Fax.
# 033 853 67
#                            Coordinates       Value
# 0  546,1364,748,1364,748,1412,546,1412  033 853 67
# 19
#                            Coordinates Value
# 0  761,1365,803,1365,803,1409,761,1409    19
# E-maj I : grossescheidegg@b luewin: ch
#                            Coordinates                                   Value
# 0  246,1415,898,1415,898,1468,246,1468  E-maj I : grossescheidegg@b luewin: ch
# /Users/neerajyadav/Documents/pycv/TestImage/Test1
# Ber qhote 1
#                        Coordinates        Value
# 0  686,416,934,416,934,472,686,472  Ber qhote 1
# Grosse Sche idegg
#                          Coordinates              Value
# 0  602,460,1053,460,1053,537,602,537  Grosse Sche idegg
# 3818 Grindelwa Id
#                        Coordinates              Value
# 0  658,513,960,513,960,563,658,563  3818 Grindelwa Id
# Fami lie R. Mul ler
#                        Coordinates                Value
# 0  658,564,960,564,960,612,658,612  Fami lie R. Mul ler
# Rech: Nr
#                        Coordinates     Value
# 0  387,667,527,667,527,711,387,711  Rech: Nr
# 4572
#                        Coordinates Value
# 0  551,667,635,667,635,709,551,709  4572
# 30.07.2007/13:29:17
#                          Coordinates                Value
# 0  824,666,1174,666,1174,714,824,714  30.07.2007/13:29:17
# Bar
#                        Coordinates Value
# 0  387,717,451,717,451,761,387,761   Bar
# Tisch
#                          Coordinates  Value
# 0  949,719,1049,719,1049,763,949,763  Tisch
# 7/01
#                            Coordinates Value
# 0  1092,718,1174,718,1174,766,1092,766  7/01
# 2xLatte Macchiato
#                        Coordinates              Value
# 0  405,821,724,821,724,865,405,865  2xLatte Macchiato
# a
#                        Coordinates Value
# 0  770,828,794,828,794,860,770,860     a
# 4.50
#                        Coordinates Value
# 0  843,821,925,821,925,863,843,863  4.50
# CHF
#                          Coordinates Value
# 0  949,821,1013,821,1013,863,949,863   CHF
# 9.00
#                            Coordinates Value
# 0  1077,823,1157,823,1157,865,1077,865  9.00
# IxGloki
#                        Coordinates    Value
# 0  409,869,539,869,539,913,409,913  IxGloki
# a
#                        Coordinates Value
# 0  773,877,793,877,793,907,773,907     a
# 5.00
#                        Coordinates Value
# 0  843,871,925,871,925,913,843,913  5.00
# CHF
#                          Coordinates Value
# 0  949,871,1015,871,1015,913,949,913   CHF
# 5.00
#                            Coordinates Value
# 0  1077,871,1159,871,1159,913,1077,913  5.00
# IxSchweinschnitze]
#                        Coordinates               Value
# 0  407,915,742,915,742,965,407,965  IxSchweinschnitze]
# a
#                        Coordinates Value
# 0  773,925,793,925,793,955,773,955     a
# 22.00
#                        Coordinates  Value
# 0  823,919,925,919,925,961,823,961  22.00
# CHF
#                          Coordinates Value
# 0  951,919,1015,919,1015,961,951,961   CHF
# 22.00
#                            Coordinates  Value
# 0  1059,919,1159,919,1159,963,1059,963  22.00
# IxChasspatz | i
#                          Coordinates            Value
# 0  407,965,650,965,650,1017,407,1017  IxChasspatz | i
# a
#                          Coordinates Value
# 0  773,975,793,975,793,1005,773,1005     a
# 18. 50
#                          Coordinates   Value
# 0  831,967,925,967,925,1011,831,1011  18. 50
# CHF
#                            Coordinates Value
# 0  951,967,1015,967,1015,1011,951,1011   CHF
# 18.50
#                              Coordinates  Value
# 0  1065,969,1161,969,1161,1011,1065,1011  18.50
# Total
#                            Coordinates  Value
# 0  625,1075,723,1075,723,1119,625,1119  Total
# CHF
#                            Coordinates Value
# 0  825,1075,891,1075,891,1117,825,1117   CHF
# 54
#                              Coordinates Value
# 0  988,1066,1054,1066,1054,1120,988,1120    54
# 50
#                                Coordinates Value
# 0  1070,1066,1134,1066,1134,1122,1070,1122    50
# Inc| .
#                            Coordinates   Value
# 0  389,1177,475,1177,475,1219,389,1219  Inc| .
# 7. 6% MwSt
#                            Coordinates       Value
# 0  497,1173,671,1173,671,1217,497,1217  7. 6% MwSt
# 54.50 CHF:
#                            Coordinates       Value
# 0  717,1173,907,1173,907,1217,717,1217  54.50 CHF:
# 3.85
#                              Coordinates Value
# 0  975,1173,1057,1173,1057,1217,975,1217  3.85
# Entspricht in Euro
#                            Coordinates               Value
# 0  384,1277,729,1277,729,1328,384,1328  Entspricht in Euro
# 36.33
#                            Coordinates  Value
# 0  773,1279,875,1279,875,1321,773,1321  36.33
# EUR
#                            Coordinates Value
# 0  898,1275,969,1275,969,1324,898,1324   EUR
# Es bediente Sie: Ursula
#                            Coordinates                    Value
# 0  382,1330,820,1330,820,1378,382,1378  Es bediente Sie: Ursula
# MwSt Nr ,
#                            Coordinates      Value
# 0  660,1432,806,1432,806,1480,660,1480  MwSt Nr ,
# 430 234
#                            Coordinates    Value
# 0  847,1433,985,1433,985,1477,847,1477  430 234
# Tel.
#                            Coordinates Value
# 0  627,1487,703,1487,703,1531,627,1531  Tel.
# 033 853 67
#                            Coordinates       Value
# 0  734,1484,932,1484,932,1532,734,1532  033 853 67
# 16
#                            Coordinates Value
# 0  943,1485,985,1485,985,1527,943,1527    16
# Fax.
#                            Coordinates Value
# 0  625,1540,704,1540,704,1584,625,1584  Fax.
# 033 853 67 19
#                            Coordinates          Value
# 0  734,1534,988,1534,988,1582,734,1582  033 853 67 19
# E-Maj ] ; grossescheidegg@b luewin ch
#                              Coordinates  \
# 0  440,1585,1080,1585,1080,1638,440,1638
#
#                                    Value
# 0  E-Maj ] ; grossescheidegg@b luewin ch

# %%
import argparse
import torch
from tqdm import tqdm
from pathlib import Path
from torch.utils.data.dataloader import DataLoader
from allennlp.data.dataset_readers.dataset_utils.span_utils import bio_tags_to_spans
from parse_config import ConfigParser
import model.pick as pick_arch_module
from data_utils.pick_dataset import PICKDataset
from data_utils.pick_dataset import BatchCollateFn
from utils.util import iob_index_to_str, text_index_to_str
import converter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-dfc935e6cc6e> in <module>
#       4 from pathlib import Path
#       5 from torch.utils.data.dataloader import DataLoader
# ----> 6 from allennlp.data.dataset_readers.dataset_utils.span_utils import bio_tags_to_spans
#       7 from parse_config import ConfigParser
#       8 import model.pick as pick_arch_module
#
# ModuleNotFoundError: No module named 'allennlp'

# %%
import os
print(os.getcwd())
path = '/Users/neerajyadav/Documents/pycv/'
os.chdir(path)
# Out:
# /Users/neerajyadav/Documents/pycv/PICK-pytorch

# %%
os.__Version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-6eb006c23e3e> in <module>
# ----> 1 os.__Version__
#
# AttributeError: module 'os' has no attribute '__Version__'

# %%
os.environ['VIRTUAL_ENV']
# Out:
# '/Users/neerajyadav/Documents/pycv/cvtorch'

# %%
# !pip install allennlp
# Out:
# Requirement already satisfied: allennlp in ./cvtorch/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: overrides==3.0.0 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (3.0.0)
# Requirement already satisfied: pytest in ./cvtorch/lib/python3.8/site-packages (from allennlp) (6.2.4)
# Requirement already satisfied: filelock<3.1,>=3.0 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (3.0.12)
# Requirement already satisfied: scikit-learn in ./cvtorch/lib/python3.8/site-packages (from allennlp) (0.24.2)
# Requirement already satisfied: requests>=2.18 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.25.1)
# Requirement already satisfied: numpy in ./cvtorch/lib/python3.8/site-packages (from allennlp) (1.17.3)
# Requirement already satisfied: jsonpickle in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.0.0)
# Requirement already satisfied: spacy<2.3,>=2.1.0 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.2.4)
# Requirement already satisfied: jsonnet>=0.10.0 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (0.17.0)
# Requirement already satisfied: scipy in ./cvtorch/lib/python3.8/site-packages (from allennlp) (1.6.3)
# Requirement already satisfied: boto3 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (1.17.93)
# Requirement already satisfied: transformers<2.12,>=2.9 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.11.0)
# Requirement already satisfied: h5py in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.10.0)
# Requirement already satisfied: nltk in ./cvtorch/lib/python3.8/site-packages (from allennlp) (3.6.2)
# Requirement already satisfied: torch<1.6.0,>=1.5.0 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (1.5.1)
# Requirement already satisfied: tensorboardX>=1.2 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (2.2)
# Requirement already satisfied: tqdm>=4.19 in ./cvtorch/lib/python3.8/site-packages (from allennlp) (4.47.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./cvtorch/lib/python3.8/site-packages (from requests>=2.18->allennlp) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./cvtorch/lib/python3.8/site-packages (from requests>=2.18->allennlp) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in ./cvtorch/lib/python3.8/site-packages (from requests>=2.18->allennlp) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./cvtorch/lib/python3.8/site-packages (from requests>=2.18->allennlp) (2021.5.30)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: setuptools in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (57.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (3.0.5)
# Requirement already satisfied: thinc==7.4.0 in ./cvtorch/lib/python3.8/site-packages (from spacy<2.3,>=2.1.0->allennlp) (7.4.0)
# Requirement already satisfied: protobuf>=3.8.0 in ./cvtorch/lib/python3.8/site-packages (from tensorboardX>=1.2->allennlp) (3.17.3)
# Requirement already satisfied: six>=1.9 in ./cvtorch/lib/python3.8/site-packages (from protobuf>=3.8.0->tensorboardX>=1.2->allennlp) (1.16.0)
# Requirement already satisfied: future in ./cvtorch/lib/python3.8/site-packages (from torch<1.6.0,>=1.5.0->allennlp) (0.18.2)
# Requirement already satisfied: regex!=2019.12.17 in ./cvtorch/lib/python3.8/site-packages (from transformers<2.12,>=2.9->allennlp) (2021.4.4)
# Requirement already satisfied: sacremoses in ./cvtorch/lib/python3.8/site-packages (from transformers<2.12,>=2.9->allennlp) (0.0.45)
# Requirement already satisfied: sentencepiece in ./cvtorch/lib/python3.8/site-packages (from transformers<2.12,>=2.9->allennlp) (0.1.95)
# Requirement already satisfied: packaging in ./cvtorch/lib/python3.8/site-packages (from transformers<2.12,>=2.9->allennlp) (20.9)
# Requirement already satisfied: tokenizers==0.7.0 in ./cvtorch/lib/python3.8/site-packages (from transformers<2.12,>=2.9->allennlp) (0.7.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.93 in ./cvtorch/lib/python3.8/site-packages (from boto3->allennlp) (1.20.93)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in ./cvtorch/lib/python3.8/site-packages (from boto3->allennlp) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./cvtorch/lib/python3.8/site-packages (from boto3->allennlp) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./cvtorch/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.93->boto3->allennlp) (2.8.1)
# Requirement already satisfied: joblib in ./cvtorch/lib/python3.8/site-packages (from nltk->allennlp) (1.0.1)
# Requirement already satisfied: click in ./cvtorch/lib/python3.8/site-packages (from nltk->allennlp) (8.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in ./cvtorch/lib/python3.8/site-packages (from packaging->transformers<2.12,>=2.9->allennlp) (2.4.7)
# Requirement already satisfied: py>=1.8.2 in ./cvtorch/lib/python3.8/site-packages (from pytest->allennlp) (1.10.0)
# Requirement already satisfied: attrs>=19.2.0 in ./cvtorch/lib/python3.8/site-packages (from pytest->allennlp) (21.2.0)
# Requirement already satisfied: iniconfig in ./cvtorch/lib/python3.8/site-packages (from pytest->allennlp) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in ./cvtorch/lib/python3.8/site-packages (from pytest->allennlp) (0.13.1)
# Requirement already satisfied: toml in ./cvtorch/lib/python3.8/site-packages (from pytest->allennlp) (0.10.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./cvtorch/lib/python3.8/site-packages (from scikit-learn->allennlp) (2.1.0)
